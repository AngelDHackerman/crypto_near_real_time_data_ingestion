# %%
import pandas as pd 
import pyarrow.parquet as pq

# %%
table = pq.read_table("../../Descargas/day1_hour23_file2.parquet")
print(table.schema)         # muestra las columnas y tipos
print(table.to_pandas().head(10))  # primeras 10 filas
# Out:
# event_time_utc: string
# asset_id: int32
# symbol: string
# name: string
# cmc_rank: int32
# circulating_supply: double
# max_supply: double
# price_usd: double
# volume_24h: double
# volume_change_24h: double
# pct_change_1h: double
# pct_change_24h: double
# pct_change_7d: double
# pct_change_30d: double
# pct_change_60d: double
# pct_change_90d: double
# market_cap: double
# market_cap_dominance: double
# fully_diluted_market_cap: double
# tvl: double
# source: string not null
# ingestion_ts_utc: timestamp[ns] not null
# -- schema metadata --
# org.apache.spark.version: '3.3.0'
# org.apache.spark.sql.parquet.row.metadata: '{"type":"struct","fields":[{"' + 1547
#         event_time_utc  asset_id symbol         name  cmc_rank  \
# 0  2025-10-01 23:03:00       825   USDT  Tether USDt         4
# 1  2025-10-01 23:33:00        74   DOGE     Dogecoin         8
# 2  2025-10-01 23:03:00      2010    ADA      Cardano        10
# 3  2025-10-01 23:13:00        52    XRP          XRP         3
# 4  2025-10-01 23:18:00      2010    ADA      Cardano        10
# 5  2025-10-01 23:08:00       825   USDT  Tether USDt         4
# 6  2025-10-01 23:13:00      2010    ADA      Cardano        10
# 7  2025-10-01 23:09:00      1027    ETH     Ethereum         2
# 8  2025-10-01 23:23:00      1958    TRX         TRON         9
# 9  2025-10-01 23:08:00      3408   USDC         USDC         7
#
#    circulating_supply    max_supply    price_usd    volume_24h  \
# 0        1.749219e+11           NaN     1.000481  1.583311e+11
# 1        1.511755e+11           NaN     0.247359  2.900597e+09
# 2        3.581889e+10  4.500000e+10     0.844844  1.366489e+09
# 3        5.987170e+10  1.000000e+11     2.934717  6.274423e+09
# 4        3.581889e+10  4.500000e+10     0.846112  1.358843e+09
# 5        1.749219e+11           NaN     1.000445  1.579369e+11
# 6        3.581889e+10  4.500000e+10     0.845468  1.356750e+09
# 7        1.207033e+08           NaN  4320.401196  4.501570e+10
# 8        9.466682e+10           NaN     0.341919  7.977593e+08
# 9        7.414538e+10           NaN     0.999830  1.869133e+10
#
#    volume_change_24h  ...  pct_change_7d  pct_change_30d  pct_change_60d  \
# 0            11.8762  ...      -0.006795        0.058885        0.053309
# 1            37.5842  ...       2.578680       18.544988       30.311547
# 2            26.5943  ...       3.562044        6.461754       20.286389
# 3            26.1453  ...      -0.132166        6.797870        5.680407
# 4            24.4592  ...       3.812264        6.570454       21.288809
# 5            11.4193  ...       0.011518        0.042355        0.062503
# 6            24.1977  ...       3.771306        6.410767       20.863918
# 7            17.1228  ...       3.912025        0.672068       27.170191
# 8            22.6552  ...       0.956524        1.505185        6.324736
# 9            14.5125  ...       0.010871        0.001241       -0.014955
#
#    pct_change_90d    market_cap  market_cap_dominance  \
# 0        0.020186  1.750060e+11                4.3441
# 1       43.672763  3.739470e+10                0.9244
# 2       40.314140  3.026137e+10                0.7512
# 3       29.701820  1.757065e+11                4.3576
# 4       40.791476  3.030678e+10                0.7512
# 5        0.012134  1.749998e+11                4.3438
# 6       40.465572  3.028372e+10                0.7510
# 7       66.369576  5.214865e+11               12.9442
# 8       19.362187  3.236834e+10                0.8002
# 9       -0.011048  7.413278e+10                1.8401
#
#    fully_diluted_market_cap  tvl  source        ingestion_ts_utc
# 0              1.791533e+11  NaN     cmc 2025-10-01 23:42:54.307
# 1              3.739470e+10  NaN     cmc 2025-10-01 23:42:54.307
# 2              3.801797e+10  NaN     cmc 2025-10-01 23:42:54.307
# 3              2.934717e+11  NaN     cmc 2025-10-01 23:42:54.307
# 4              3.807502e+10  NaN     cmc 2025-10-01 23:42:54.307
# 5              1.791470e+11  NaN     cmc 2025-10-01 23:42:54.307
# 6              3.804605e+10  NaN     cmc 2025-10-01 23:42:54.307
# 7              5.214865e+11  NaN     cmc 2025-10-01 23:42:54.307
# 8              3.236834e+10  NaN     cmc 2025-10-01 23:42:54.307
# 9              7.413278e+10  NaN     cmc 2025-10-01 23:42:54.307
#
# [10 rows x 22 columns]

# %%
df = table.to_pandas()
df = df.sort_values(by='asset_id')
df.head(12)
# Out:
#          event_time_utc  asset_id symbol     name  cmc_rank  \
# 27  2025-10-01 23:03:00         1    BTC  Bitcoin         1
# 26  2025-10-01 23:33:00         1    BTC  Bitcoin         1
# 47  2025-10-01 23:18:00         1    BTC  Bitcoin         1
# 38  2025-10-01 23:13:00         1    BTC  Bitcoin         1
# 51  2025-10-01 23:28:00         1    BTC  Bitcoin         1
# 59  2025-10-01 23:08:00         1    BTC  Bitcoin         1
# 76  2025-10-01 23:23:00         1    BTC  Bitcoin         1
# 3   2025-10-01 23:13:00        52    XRP      XRP         3
# 31  2025-10-01 23:03:00        52    XRP      XRP         3
# 34  2025-10-01 23:18:00        52    XRP      XRP         3
# 58  2025-10-01 23:08:00        52    XRP      XRP         3
# 60  2025-10-01 23:23:00        52    XRP      XRP         3
#
#     circulating_supply    max_supply      price_usd    volume_24h  \
# 27        1.992820e+07  2.100000e+07  117781.841416  6.919065e+10
# 26        1.992820e+07  2.100000e+07  118348.786043  7.060688e+10
# 47        1.992820e+07  2.100000e+07  118259.786290  6.832919e+10
# 38        1.992820e+07  2.100000e+07  117931.257085  6.838671e+10
# 51        1.992820e+07  2.100000e+07  118352.753268  6.956851e+10
# 59        1.992820e+07  2.100000e+07  117894.774076  6.903842e+10
# 76        1.992820e+07  2.100000e+07  118336.771413  6.920442e+10
# 3         5.987170e+10  1.000000e+11       2.934717  6.274423e+09
# 31        5.987170e+10  1.000000e+11       2.931318  6.279219e+09
# 34        5.987170e+10  1.000000e+11       2.935735  6.279500e+09
# 58        5.987170e+10  1.000000e+11       2.933719  6.269657e+09
# 60        5.987170e+10  1.000000e+11       2.942625  6.296373e+09
#
#     volume_change_24h  ...  pct_change_7d  pct_change_30d  pct_change_60d  \
# 27            15.4517  ...       3.840733        8.397420        4.449647
# 26            19.6209  ...       4.452636        8.855707        5.394454
# 47            15.7011  ...       4.324072        8.793621        5.020256
# 38            14.1524  ...       3.996880        8.452650        4.766671
# 51            18.9812  ...       4.359371        8.880929        5.348912
# 59            15.2027  ...       3.963537        8.625736        4.573639
# 76            15.8596  ...       4.471291        8.919388        5.287498
# 3             26.1453  ...      -0.132166        6.797870        5.680407
# 31            26.4154  ...      -0.453707        6.640260        4.927218
# 34            26.4574  ...      -0.020714        6.951737        6.034637
# 58            25.9577  ...      -0.323508        6.815623        5.133758
# 60            26.8639  ...       0.294319        7.176972        6.522235
#
#     pct_change_90d    market_cap  market_cap_dominance  \
# 27        7.288975  2.347180e+12               58.2637
# 26        7.946121  2.358479e+12               58.3025
# 47        7.849483  2.356705e+12               58.4130
# 38        7.509457  2.350158e+12               58.2845
# 51        7.966717  2.358558e+12               58.3011
# 59        7.347866  2.349431e+12               58.3169
# 76        7.983707  2.358239e+12               58.3006
# 3        29.701820  1.757065e+11                4.3576
# 31       29.409253  1.755030e+11                4.3565
# 34       29.972130  1.757674e+11                4.3566
# 58       29.445506  1.756468e+11                4.3599
# 60       30.379242  1.761799e+11                4.3555
#
#     fully_diluted_market_cap  tvl  source        ingestion_ts_utc
# 27              2.473419e+12  NaN     cmc 2025-10-01 23:42:54.307
# 26              2.485325e+12  NaN     cmc 2025-10-01 23:42:54.307
# 47              2.483456e+12  NaN     cmc 2025-10-01 23:42:54.307
# 38              2.476556e+12  NaN     cmc 2025-10-01 23:42:54.307
# 51              2.485408e+12  NaN     cmc 2025-10-01 23:42:54.307
# 59              2.475790e+12  NaN     cmc 2025-10-01 23:42:54.307
# 76              2.485072e+12  NaN     cmc 2025-10-01 23:42:54.307
# 3               2.934717e+11  NaN     cmc 2025-10-01 23:42:54.307
# 31              2.931318e+11  NaN     cmc 2025-10-01 23:42:54.307
# 34              2.935735e+11  NaN     cmc 2025-10-01 23:42:54.307
# 58              2.933719e+11  NaN     cmc 2025-10-01 23:42:54.307
# 60              2.942625e+11  NaN     cmc 2025-10-01 23:42:54.307
#
# [12 rows x 22 columns]

# %%
print("Filas totales:", len(df))
print("Assets distintos:", df["asset_id"].nunique())
print("Symbols distintos:", df["symbol"].nunique())

# Ver supplies para sanity check
print(df[["asset_id", "symbol", "circulating_supply", "max_supply"]].head(20))

# Checar nulos
print(df[["circulating_supply", "max_supply"]].isna().sum())
# Out:
# Filas totales: 77
# Assets distintos: 11
# Symbols distintos: 11
#     asset_id symbol  circulating_supply    max_supply
# 27         1    BTC        1.992820e+07  2.100000e+07
# 26         1    BTC        1.992820e+07  2.100000e+07
# 47         1    BTC        1.992820e+07  2.100000e+07
# 38         1    BTC        1.992820e+07  2.100000e+07
# 51         1    BTC        1.992820e+07  2.100000e+07
# 59         1    BTC        1.992820e+07  2.100000e+07
# 76         1    BTC        1.992820e+07  2.100000e+07
# 3         52    XRP        5.987170e+10  1.000000e+11
# 31        52    XRP        5.987170e+10  1.000000e+11
# 34        52    XRP        5.987170e+10  1.000000e+11
# 58        52    XRP        5.987170e+10  1.000000e+11
# 60        52    XRP        5.987170e+10  1.000000e+11
# 67        52    XRP        5.987170e+10  1.000000e+11
# 11        52    XRP        5.987170e+10  1.000000e+11
# 32        74   DOGE        1.511755e+11           NaN
# 1         74   DOGE        1.511755e+11           NaN
# 61        74   DOGE        1.511755e+11           NaN
# 69        74   DOGE        1.511755e+11           NaN
# 62        74   DOGE        1.511755e+11           NaN
# 48        74   DOGE        1.511752e+11           NaN
# circulating_supply     0
# max_supply            56
# dtype: int64
